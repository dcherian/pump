# %% [markdown]
# # PUMP catalog
#
# TODO:
# - [ ] Add MITgcm
# - [ ] Display LES too
# - [ ] Obs catalog

# %%
# %load_ext watermark

from pathlib import Path

from ecgtools import Builder

# %watermark -iv
# Out:
# json: 2.0.9
# sys : 3.10.10 | packaged by conda-forge | (main, Mar 24 2023, 20:08:06) [GCC 11.3.0]

# %%
ROOT = Path("/glade/campaign/cgd/oce/projects/pump/cesm/")

# %%
# MOM6 run catalog
catalog = {
    "baseline": (
        "baseline",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline.001.mixpods",
    ),
    "epbl": ("ePBL", "gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline.epbl.001.mixpods"),
    "kpp.lmd.002": (
        "KPP Ri0=0.5",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline.kpp.lmd.002.mixpods",
    ),
    "kpp.lmd.003": (
        "KPP Ri0=0.5, Ric=0.2,",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline.kpp.lmd.003.mixpods",
    ),
    "kpp.lmd.004": (
        "KPP ν0=2.5, Ric=0.2, Ri0=0.5",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline.kpp.lmd.004.mixpods",
    ),
    "baseline.N150": (
        "baseline N=150",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N150.baseline.mixpods",
    ),
    "kpp.lmd.004.N150": (
        "KPP ν0=2.5, Ric=0.2, Ri0=0.5, N=150",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N150.kpp.lmd.004.mixpods",
    ),
    "new_baseline.hb": (
        "KD=0, KV=0",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_baseline.hb",
    ),
    "new_baseline.kpp.lmd.004": (
        "KPP ν0=2.5, Ric=0.2, Ri0=0.5",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_baseline.kpp.lmd.004",
    ),
    "new_baseline.kpp.lmd.005": (
        "KPP ν0=2.5, Ri0=0.5",
        "gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_baseline.kpp.lmd.005",
    ),
}

# %%
simnames = [v[-1] for v in catalog.values()]
path = list((ROOT / simnames[-3] / "run" / "jsons").glob("*.json"))[-1]

# %%
METRIC_VARS = {
    "Coriolis",
    "areacello",
    "areacello_bu",
    "areacello_cu",
    "areacello_cv",
    "cos_rot",
    "deptho",
    "geolat",
    "geolat_c",
    "geolat_u",
    "geolat_v",
    "geolon",
    "geolon_c",
    "geolon_u",
    "geolon_v",
    "nv",
    "sin_rot",
    "wet",
    "wet_c",
    "wet_u",
    "wet_v",
    "xh",
    "xq",
    "yh",
    "yq",
    "zi",
}

IGNORE_VARS = {
    "average_DT",
    "average_T1",
    "average_T2",
    "time",
    "time_bnds",
    "z_i",
    "z_l",
}


def parse_cesm_mom6_kerchunk_json(file, storage_options=None):
    """Parser for CESM timeseries files"""
    import warnings
    from pathlib import Path

    import fsspec

    import xarray as xr

    if storage_options is None:
        storage_options = {}

    path = Path(file)

    info = dict()
    info["casename"] = path.parts[-4]
    info["stream"] = path.stem
    info["path"] = file
    info["baseline"] = "new" if "new_baseline" in info["casename"] else "old"
    info["levels"] = int(path.parts[-4].split(".")[3].split("_")[-1][1:])

    fs = fsspec.filesystem("reference", fo=file, **storage_options)
    mapper = fs.get_mapper("")

    if path.stem == "combined":
        info["frequency"] = "N/A"
        dt = datatree.open_datatree(
            mapper, engine="zarr", use_cftime=True, consolidated=False
        )
        variables = itertools.chain(*[node.variables.keys() for node in dt.subtree])
        if not dt:
            warnings.warn(f"bad file: {file}", RuntimeWarning)
            dt.close()
            return
    else:
        ds = xr.open_zarr(
            mapper,
            use_cftime=True,
            consolidated=False,
            chunks={},
        )
        if not ds:
            warnings.warn(f"bad file: {file}", RuntimeWarning)
            ds.close()
            return
        # TODO: Use keith's util
        info["frequency"] = "daily" if xr.infer_freq(ds.time) == "D" else "monthly"
        variables = ds.variables.keys()

    info["variables"] = sorted(set(variables) - set(METRIC_VARS) - set(IGNORE_VARS))

    return info


path = (
    "/glade/campaign/cgd/oce/projects/pump/cesm/gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_baseline.hb/"
    "run/jsons/combined.json"
)
parse_cesm_mom6_kerchunk_json(str(path))

# %% [markdown]
# ## Make catalog

# %%
builder = Builder(paths=tuple(str(p) for p in ROOT.glob("**/run/jsons/")), depth=0)

# %%
builder.build(parsing_func=parse_cesm_mom6_kerchunk_json)

# %%
builder.save(
    name="../pump-catalog",
    # Column name including filepath
    path_column_name="path",
    # Column name including variables
    variable_column_name="variables",
    # Data file format - could be netcdf or zarr or reference (in this case, netcdf)
    data_format="reference",
    # Which attributes to groupby when reading in variables using intake-esm
    groupby_attrs=["casename", "stream"],
    # Aggregations which are fed into xarray when reading in data using intake
    aggregations=[],
)

# %% [markdown]
# ## Read Catalog

# %%
import intake

data_catalog = intake.open_esm_datastore("../pump-catalog.json")
data_catalog
# Out:
# <p><strong>../pump-catalog catalog with 32 dataset(s) from 32 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>casename</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>stream</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>baseline</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>levels</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>variables</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>derived_variables</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data_catalog.df
# Out:
#                                              casename    stream  \
# 0   gmom.e23.GJRAv3.TL319_t061_zstar_N150.baseline...  combined
# 1   gmom.e23.GJRAv3.TL319_t061_zstar_N150.baseline...       sfc
# 2   gmom.e23.GJRAv3.TL319_t061_zstar_N150.kpp.lmd....  combined
# 3   gmom.e23.GJRAv3.TL319_t061_zstar_N150.kpp.lmd....       sfc
# 4   gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....  combined
# 5   gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....         h
# 6   gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       sfc
# 7   gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....  combined
# 8   gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....         h
# 9   gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       sfc
# 10  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       wci
# 11  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....  combined
# 12  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....         h
# 13  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       sfc
# 14  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       wci
# 15  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....  combined
# 16  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....         h
# 17  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       sfc
# 18  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       wci
# 19  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....  combined
# 20  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....         h
# 21  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       sfc
# 22  gmom.e23.GJRAv3.TL319_t061_zstar_N65.baseline....       wci
# 23  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...  combined
# 24  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...         h
# 25  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...       sfc
# 26  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...  combined
# 27  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...         h
# 28  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...       sfc
# 29  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...  combined
# 30  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...         h
# 31  gmom.e23.GJRAv3.TL319_t061_zstar_N65.new_basel...       sfc
#
#                                                  path baseline  levels  \
# 0   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old     150
# 1   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old     150
# 2   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old     150
# 3   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old     150
# 4   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 5   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 6   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 7   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 8   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 9   /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 10  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 11  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 12  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 13  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 14  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 15  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 16  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 17  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 18  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 19  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 20  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 21  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 22  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      old      65
# 23  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 24  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 25  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 26  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 27  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 28  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 29  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 30  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
# 31  /glade/campaign/cgd/oce/projects/pump/cesm/gmo...      new      65
#
#    frequency                                          variables
# 0        NaN  ['SSH', 'SSU', 'SSV', 'mlotst', 'oml', 'sos', ...
# 1      daily  ['SSH', 'SSU', 'SSV', 'mlotst', 'oml', 'sos', ...
# 2        NaN  ['SSH', 'SSU', 'SSV', 'mlotst', 'oml', 'sos', ...
# 3      daily  ['SSH', 'SSU', 'SSV', 'mlotst', 'oml', 'sos', ...
# 4        NaN  ['N2_int', 'Rd_dx', 'SSH', 'SSU', 'SSV', 'ages...
# 5    monthly  ['N2_int', 'agessc', 'h', 'rhopot0', 'so', 'th...
# 6    monthly  ['Rd_dx', 'SSH', 'SSU', 'SSV', 'mass_wt', 'mlo...
# 7        NaN  ['SSH', 'SSU', 'SSV', 'T_advection_xy', 'T_lbd...
# 8    monthly  ['h', 'so', 'thetao', 'uhGM', 'uhml', 'umo', '...
# 9    monthly  ['SSH', 'SSU', 'SSV', 'mlotst', 'sos', 'speed'...
# 10   monthly  ['T_advection_xy', 'T_lbdxy_cont_tendency', 'T...
# 11       NaN  ['KPP_NLT_temp_budget', 'SSH', 'SSU', 'SSV', '...
# 12   monthly  ['h', 'so', 'thetao', 'uhGM', 'uhml', 'umo', '...
# 13   monthly  ['SSH', 'SSU', 'SSV', 'mlotst', 'oml', 'sos', ...
# 14   monthly  ['KPP_NLT_temp_budget', 'T_advection_xy', 'T_l...
# 15       NaN  ['KPP_NLT_temp_budget', 'SSH', 'SSU', 'SSV', '...
# 16   monthly  ['h', 'so', 'thetao', 'uhGM', 'uhml', 'umo', '...
# 17   monthly  ['SSH', 'SSU', 'SSV', 'mlotst', 'oml', 'sos', ...
# 18   monthly  ['KPP_NLT_temp_budget', 'T_advection_xy', 'T_l...
# 19       NaN  ['KPP_NLT_temp_budget', 'SSH', 'SSU', 'SSV', '...
# 20   monthly  ['h', 'so', 'thetao', 'uhGM', 'uhml', 'umo', '...
# 21   monthly  ['SSH', 'SSU', 'SSV', 'mlotst', 'oml', 'sos', ...
# 22   monthly  ['KPP_NLT_temp_budget', 'T_advection_xy', 'T_l...
# 23       NaN  ['N2_int', 'Rd_dx', 'SSH', 'SSU', 'SSV', 'ages...
# 24   monthly  ['N2_int', 'agessc', 'h', 'rhopot0', 'so', 'th...
# 25     daily  ['Rd_dx', 'SSH', 'SSU', 'SSV', 'mass_wt', 'mlo...
# 26       NaN  ['N2_int', 'Rd_dx', 'SSH', 'SSU', 'SSV', 'ages...
# 27   monthly  ['N2_int', 'agessc', 'h', 'rhopot0', 'so', 'th...
# 28     daily  ['Rd_dx', 'SSH', 'SSU', 'SSV', 'mass_wt', 'mlo...
# 29       NaN  ['N2_int', 'Rd_dx', 'SSH', 'SSU', 'SSV', 'ages...
# 30   monthly  ['N2_int', 'agessc', 'h', 'rhopot0', 'so', 'th...
# 31     daily  ['Rd_dx', 'SSH', 'SSU', 'SSV', 'mass_wt', 'mlo...

# %% [markdown]
# ## Display interactive catalog

# %%
def catalog_to_grid(data_catalog):
    import ipyaggrid

    def make_short_name(casename_split):
        trimmed = casename_split[4:]
        if trimmed[-1] == "mixpods":
            trimmed = trimmed[:-1]
        return ".".join(trimmed)

    df = data_catalog.df
    df = df.assign(shortname=df.casename.str.split(".").map(make_short_name))

    column_defs = [
        {
            "headerName": "shortname",
            "field": "shortname",
            "rowGroup": False,
            "pinned": True,
        },
        {"headerName": "stream", "field": "stream", "rowGroup": False},
        {"headerName": "baseline", "field": "baseline"},
        {"headerName": "frequency", "field": "frequency", "rowGroup": False},
        {"headerName": "levels", "field": "levels", "rowGroup": False},
        {"headerName": "variables", "field": "variables", "autoHeight": True},
        {"headerName": "casename", "field": "casename", "rowGroup": False},
        {"headerName": "path", "field": "path", "rowGroup": False},
    ]

    grid_options = {
        "columnDefs": column_defs,
        "defaultColDef": {
            "resizable": True,
            "editable": False,
            "filter": True,
            "sortable": True,
        },
        "colResizeDefault": True,
        "enableRangeSelection": True,
        "statusBar": {  # new syntax since 19.0
            "statusPanels": [
                {"statusPanel": "agTotalRowCountComponent", "align": "left"},
                {"statusPanel": "agFilteredRowCountComponent"},
                {"statusPanel": "agSelectedRowCountComponent"},
                {"statusPanel": "agAggregationComponent"},
            ]
        },
        # "enableRangeHandle": True,
    }

    g = ipyaggrid.Grid(
        grid_data=df,
        grid_options=grid_options,
        quick_filter=True,
        export_csv=False,
        export_excel=False,
        export_mode="buttons",
        export_to_df=True,
        theme="ag-theme-balham",
        # show_toggle_edit=False,
        # show_toggle_delete=False,
        columns_fit="auto",
        # index=False,
        # keep_multiindex=False,
    )
    return g

# %%
grid = catalog_to_grid(data_catalog)
grid
# Out:
# Grid(columns_fit='auto', compress_data=True, export_mode='buttons', height='350px', menu={'buttons': [{'name':…

# %% [markdown]
# ### Export HTML to view

# %%
from IPython.display import HTML

html = grid.export_html(build=True)
HTML(html)
# Out:
# <!-- Load RequireJS, used by the IPywidgets for dependency management -->
# <script
#   src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js"
#   integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA="
#   crossorigin="anonymous">
# </script>
#
# <!-- Load IPywidgets bundle for embedding. -->
# <script
#   src="https://unpkg.com/@jupyter-widgets/html-manager@*/dist/embed-amd.js"
#   crossorigin="anonymous">
# </script>
# <!-- The state of all the widget models on the page -->
# <script type="application/vnd.jupyter.widget-state+json">
#   {"version_major": 2, "version_minor": 0, "state": {"2423c78fa79c4dbfa6ac6d7c2497e4ec": {"model_name": "AgGridModel", "model_module": "ipyaggrid", "model_module_version": "~0.3.2", "state": {"_cell_updates": [], "_dom_classes": [], "_grid_data_down": "\n", "_grid_data_up": {}, "_grid_options_mono_down": "\no25sp5R2xWKbcUcVkeCLd/k+AJeZ4hZbBQAA\n", "_grid_options_multi_down": [], "_id": 753058, "_js_helpers_builtin": "\n", "columns_fit": "auto", "compress_data": true, "css_rules_down": [], "export_mode": "buttons", "height": "350px", "js_helpers_custom": "H4sIANmCNWQC/wMAAAAAAAAAAAA=\n", "js_post_grid": [], "js_pre_grid": [], "js_pre_helpers": [], "layout": "IPY_MODEL_bee08747bf104b6fb18f5004bb123347", "menu": {"buttons": [{"name": "Export Grid", "action": "exportFunc.exportGrid(gridOptions, view, parseInt(inputAggregationLevel.value, 10))", "container_css": ".flex-child-container-export-grid-753058 {\norder: 0;\nalign-self: auto;\nwidth: 150px;\nma ...
# </script>
# <div id="embed-grid-753058">
#   <!-- This script tag will be replaced by the views DOM tree -->
#   <script type="application/vnd.jupyter.widget-view+json">
#     {"version_major": 2, "version_minor": 0, "model_id": "2423c78fa79c4dbfa6ac6d7c2497e4ec"}
#   </script>
# </div>
